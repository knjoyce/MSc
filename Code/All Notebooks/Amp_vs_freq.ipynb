# %% [markdown]
# ## Amplitude vs Freqency

# %%
# Import Data

exec(open('ComputeDelays.py').read())

# 1 cycle
Aluminium_100L1=timedata('Aluminium_100L1')
readlabdat('jun10_1.csv',Aluminium_100L1)

Aluminium_300L1=timedata('Aluminium_300L1')
readlabdat('jun10_2.csv',Aluminium_300L1)

Aluminium_500L1=timedata('Aluminium_500L1')
readlabdat('jun10_3.csv',Aluminium_500L1)

Aluminium_800L1=timedata('Aluminium_800L1')
readlabdat('jun10_4.csv',Aluminium_800L1)

Aluminium_1000L1=timedata('Aluminium_1000L1')
readlabdat('jun10_5.csv',Aluminium_1000L1)

# 4 cycles
Aluminium_100L4=timedata('Aluminium_100L4')
readlabdat('jun10_6.csv',Aluminium_100L4)

Aluminium_300L4=timedata('Aluminium_300L4')
readlabdat('jun10_7.csv',Aluminium_300L4)

Aluminium_500L4=timedata('Aluminium_500L4')
readlabdat('jun10_8.csv',Aluminium_500L4)

Aluminium_800L4=timedata('Aluminium_800L4')
readlabdat('jun10_9.csv',Aluminium_800L4)

Aluminium_1000L4=timedata('Aluminium_1000L4')
readlabdat('jun10_10.csv',Aluminium_1000L4)

# continuous cycles
Aluminium_100LC=timedata('Aluminium_100LC')
readlabdat('jun10_11.csv',Aluminium_100LC)

Aluminium_300LC=timedata('Aluminium_300LC')
readlabdat('jun10_12.csv',Aluminium_300LC)

Aluminium_500LC=timedata('Aluminium_500LC')
readlabdat('jun10_13.csv',Aluminium_500LC)

Aluminium_800LC=timedata('Aluminium_800LC')
readlabdat('jun10_14.csv',Aluminium_800LC)

Aluminium_1000LC=timedata('Aluminium_1000LC')
readlabdat('jun10_15.csv',Aluminium_1000LC)

# %%
# FFT

# 1 cycle
n_Aluminium_100L1=np.size(Aluminium_100L1.time)
dt_Aluminium_100L1=(Aluminium_100L1.time[2]-Aluminium_100L1.time[1])*1e6
f_Aluminium_100L1=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_100L1,d=dt_Aluminium_100L1))*1000
FT_Aluminium_100L1=np.fft.fftshift(np.fft.fft(Aluminium_100L1.data - np.mean(Aluminium_100L1.data)))

n_Aluminium_300L1=np.size(Aluminium_300L1.time)
dt_Aluminium_300L1=(Aluminium_300L1.time[2]-Aluminium_300L1.time[1])*1e6
f_Aluminium_300L1=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_300L1,d=dt_Aluminium_300L1))*1000
FT_Aluminium_300L1=np.fft.fftshift(np.fft.fft(Aluminium_300L1.data - np.mean(Aluminium_300L1.data)))

n_Aluminium_500L1=np.size(Aluminium_500L1.time)
dt_Aluminium_500L1=(Aluminium_500L1.time[2]-Aluminium_500L1.time[1])*1e6
f_Aluminium_500L1=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_500L1,d=dt_Aluminium_500L1))*1000
FT_Aluminium_500L1=np.fft.fftshift(np.fft.fft(Aluminium_500L1.data - np.mean(Aluminium_500L1.data)))

n_Aluminium_800L1=np.size(Aluminium_800L1.time)
dt_Aluminium_800L1=(Aluminium_800L1.time[2]-Aluminium_800L1.time[1])*1e6
f_Aluminium_800L1=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_800L1,d=dt_Aluminium_800L1))*1000
FT_Aluminium_800L1=np.fft.fftshift(np.fft.fft(Aluminium_800L1.data - np.mean(Aluminium_800L1.data)))

n_Aluminium_1000L1=np.size(Aluminium_1000L1.time)
dt_Aluminium_1000L1=(Aluminium_1000L1.time[2]-Aluminium_1000L1.time[1])*1e6
f_Aluminium_1000L1=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_1000L1,d=dt_Aluminium_1000L1))*1000
FT_Aluminium_1000L1=np.fft.fftshift(np.fft.fft(Aluminium_1000L1.data - np.mean(Aluminium_1000L1.data)))


# 4 cycles
n_Aluminium_100L4=np.size(Aluminium_100L4.time)
dt_Aluminium_100L4=(Aluminium_100L4.time[2]-Aluminium_100L4.time[1])*1e6
f_Aluminium_100L4=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_100L4,d=dt_Aluminium_100L4))*1000
FT_Aluminium_100L4=np.fft.fftshift(np.fft.fft(Aluminium_100L4.data - np.mean(Aluminium_100L4.data)))

n_Aluminium_300L4=np.size(Aluminium_300L4.time)
dt_Aluminium_300L4=(Aluminium_300L4.time[2]-Aluminium_300L4.time[1])*1e6
f_Aluminium_300L4=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_300L4,d=dt_Aluminium_300L4))*1000
FT_Aluminium_300L4=np.fft.fftshift(np.fft.fft(Aluminium_300L4.data - np.mean(Aluminium_300L4.data)))

n_Aluminium_500L4=np.size(Aluminium_500L4.time)
dt_Aluminium_500L4=(Aluminium_500L4.time[2]-Aluminium_500L4.time[1])*1e6
f_Aluminium_500L4=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_500L4,d=dt_Aluminium_500L4))*1000
FT_Aluminium_500L4=np.fft.fftshift(np.fft.fft(Aluminium_500L4.data - np.mean(Aluminium_500L4.data)))

n_Aluminium_800L4=np.size(Aluminium_800L4.time)
dt_Aluminium_800L4=(Aluminium_800L4.time[2]-Aluminium_800L4.time[1])*1e6
f_Aluminium_800L4=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_800L4,d=dt_Aluminium_800L4))*1000
FT_Aluminium_800L4=np.fft.fftshift(np.fft.fft(Aluminium_800L4.data - np.mean(Aluminium_800L4.data)))

n_Aluminium_1000L4=np.size(Aluminium_1000L4.time)
dt_Aluminium_1000L4=(Aluminium_1000L4.time[2]-Aluminium_1000L4.time[1])*1e6
f_Aluminium_1000L4=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_1000L4,d=dt_Aluminium_1000L4))*1000
FT_Aluminium_1000L4=np.fft.fftshift(np.fft.fft(Aluminium_1000L4.data - np.mean(Aluminium_1000L4.data)))


# continuous
n_Aluminium_100LC=np.size(Aluminium_100LC.time)
dt_Aluminium_100LC=(Aluminium_100LC.time[2]-Aluminium_100LC.time[1])*1e6
f_Aluminium_100LC=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_100LC,d=dt_Aluminium_100LC))*1000
FT_Aluminium_100LC=np.fft.fftshift(np.fft.fft(Aluminium_100LC.data - np.mean(Aluminium_100LC.data)))

n_Aluminium_300LC=np.size(Aluminium_300LC.time)
dt_Aluminium_300LC=(Aluminium_300LC.time[2]-Aluminium_300LC.time[1])*1e6
f_Aluminium_300LC=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_300LC,d=dt_Aluminium_300LC))*1000
FT_Aluminium_300LC=np.fft.fftshift(np.fft.fft(Aluminium_300LC.data - np.mean(Aluminium_300LC.data)))

n_Aluminium_500LC=np.size(Aluminium_500LC.time)
dt_Aluminium_500LC=(Aluminium_500LC.time[2]-Aluminium_500LC.time[1])*1e6
f_Aluminium_500LC=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_500LC,d=dt_Aluminium_500LC))*1000
FT_Aluminium_500LC=np.fft.fftshift(np.fft.fft(Aluminium_500LC.data - np.mean(Aluminium_500LC.data)))

n_Aluminium_800LC=np.size(Aluminium_800LC.time)
dt_Aluminium_800LC=(Aluminium_800LC.time[2]-Aluminium_800LC.time[1])*1e6
f_Aluminium_800LC=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_800LC,d=dt_Aluminium_800LC))*1000
FT_Aluminium_800LC=np.fft.fftshift(np.fft.fft(Aluminium_800LC.data - np.mean(Aluminium_800LC.data)))

n_Aluminium_1000LC=np.size(Aluminium_1000LC.time)
dt_Aluminium_1000LC=(Aluminium_1000LC.time[2]-Aluminium_1000LC.time[1])*1e6
f_Aluminium_1000LC=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_1000LC,d=dt_Aluminium_1000LC))*1000
FT_Aluminium_1000LC=np.fft.fftshift(np.fft.fft(Aluminium_1000LC.data - np.mean(Aluminium_1000LC.data)))

# %%
max_C = np.max(np.abs(FT_Aluminium_1000LC)) # found visually from FFT_plots notebook
max_4 = np.max(np.abs(FT_Aluminium_100L4)) # found visually from FFT_plots notebook
max_1 = np.max(np.abs(FT_Aluminium_100L1)) # found visually from FFT_plots notebook

max_100C = np.max(np.abs(FT_Aluminium_100LC)/max_C)
max_300C = np.max(np.abs(FT_Aluminium_300LC)/max_C)
max_500C = np.max(np.abs(FT_Aluminium_500LC)/max_C)
max_800C = np.max(np.abs(FT_Aluminium_800LC)/max_C)
max_1000C = np.max(np.abs(FT_Aluminium_1000LC)/max_C)

max_1004 = np.max(np.abs(FT_Aluminium_100L4)/max_4)
max_3004 = np.max(np.abs(FT_Aluminium_300L4)/max_4)
max_5004 = np.max(np.abs(FT_Aluminium_500L4)/max_4)
max_8004 = np.max(np.abs(FT_Aluminium_800L4)/max_4)
max_10004 = np.max(np.abs(FT_Aluminium_1000L4)/max_4)

max_1001 = np.max(np.abs(FT_Aluminium_100L1)/max_1)
max_3001 = np.max(np.abs(FT_Aluminium_300L1)/max_1)
max_5001 = np.max(np.abs(FT_Aluminium_500L1)/max_1)
max_8001 = np.max(np.abs(FT_Aluminium_800L1)/max_1)
max_10001 = np.max(np.abs(FT_Aluminium_1000L1)/max_1)

# %%
amplitudes_C = [max_100C,max_300C,max_500C,max_800C,max_1000C]
amplitudes_4 = [max_1004,max_3004,max_5004,max_8004,max_10004]
amplitudes_1 = [max_1001,max_3001,max_5001,max_8001,max_10001]
freqs = [100,300,500,800,1000] 

plt.figure(1)
plt.plot(freqs,amplitudes_C, label="Continous")
plt.plot(freqs,amplitudes_4, label="4 Cycles")
plt.plot(freqs,amplitudes_1, label="1 Cycle")
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Amplitude')
plt.title('FFT Amplitude vs Frequency - Aluminium (Normalized to Max)')
plt.savefig("Amp_vsFreq_Aluminium.png",dpi=300)

# %% [markdown]
# # compare voltage scale adjustments

# %%
Sand_1=timedata('Sand_1')
readlabdat('jun17_12.csv',Sand_1)

Sand_2=timedata('Sand_2')
readlabdat('jun17_10.csv',Sand_2)

Sand_5=timedata('Sand_5')
readlabdat('jun17_11.csv',Sand_5)

plt.plot(Sand_1.time*1e6,Sand_1.data,label="1 mV")
plt.plot(Sand_2.time*1e6,Sand_2.data,label="2 mV")
plt.plot(Sand_5.time*1e6,Sand_5.data,label="5 mV")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.xlim(-10,20)
plt.title('Voltage Scale Comparison - Sandstone - 1 MHz')
plt.savefig("VoltageScale_Sandstone.png",dpi=300)

# %%
n_Sand_1=np.size(Sand_1.time)
dt_Sand_1=(Sand_1.time[2]-Sand_1.time[1])*1e6
f_Sand_1=np.fft.fftshift(np.fft.fftfreq(n_Sand_1,d=dt_Sand_1))*1000
FT_Sand_1=np.fft.fftshift(np.fft.fft(Sand_1.data - np.mean(Sand_1.data)))

n_Sand_2=np.size(Sand_2.time)
dt_Sand_2=(Sand_2.time[2]-Sand_2.time[1])*1e6
f_Sand_2=np.fft.fftshift(np.fft.fftfreq(n_Sand_2,d=dt_Sand_2))*1000
FT_Sand_2=np.fft.fftshift(np.fft.fft(Sand_2.data - np.mean(Sand_2.data)))

n_Sand_5=np.size(Sand_5.time)
dt_Sand_5=(Sand_5.time[2]-Sand_5.time[1])*1e6
f_Sand_5=np.fft.fftshift(np.fft.fftfreq(n_Sand_5,d=dt_Sand_5))*1000
FT_Sand_5=np.fft.fftshift(np.fft.fft(Sand_5.data - np.mean(Sand_5.data)))

plt.plot(f_Sand_1,np.abs(FT_Sand_1), label="1 mV")
plt.plot(f_Sand_2,np.abs(FT_Sand_2), label="2 mV")
plt.plot(f_Sand_5,np.abs(FT_Sand_5), label="5 mV")

plt.xlim([-1500,1500])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Sandstone FFT, Voltage Scale Comparison - 1 MHz')
plt.savefig("FFTVoltageScale_Sandstone.png",dpi=300)

# %%
# 1 cycle
Sandstone_100_1=timedata('Sandstone_100_1')
readlabdat('jun17_1.csv',Sandstone_100_1)

Sandstone_300_1=timedata('Sandstone_300_1')
readlabdat('jun17_2.csv',Sandstone_300_1)

Sandstone_500_1=timedata('Sandstone_500_1')
readlabdat('jun17_3.csv',Sandstone_500_1)

Sandstone_800_1=timedata('Sandstone_800_1')
readlabdat('jun17_4.csv',Sandstone_800_1)

Sandstone_1000_1=timedata('Sandstone_1000_1')
readlabdat('jun17_5.csv',Sandstone_1000_1)

# 4 cycles
Sandstone_100_4=timedata('Sandstone_100_4')
readlabdat('jun17_6.csv',Sandstone_100_4)

Sandstone_300_4=timedata('Sandstone_300_4')
readlabdat('jun17_7.csv',Sandstone_300_4)

Sandstone_500_4=timedata('Sandstone_500_4')
readlabdat('jun17_8.csv',Sandstone_500_4)

Sandstone_800_4=timedata('Sandstone_800_4')
readlabdat('jun17_9.csv',Sandstone_800_4)

Sandstone_1000_4=timedata('Sandstone_1000_4')
readlabdat('jun17_10.csv',Sandstone_1000_4)

# continous
Sandstone_100_C=timedata('Sandstone_100_C')
readlabdat('jun2_8.csv',Sandstone_100_C)

Sandstone_300_C=timedata('Sandstone_300_C')
readlabdat('jun2_9.csv',Sandstone_300_C)

Sandstone_500_C=timedata('Sandstone_500_C')
readlabdat('jun2_10.csv',Sandstone_500_C)

Sandstone_800_C=timedata('Sandstone_800_C')
readlabdat('jun2_11.csv',Sandstone_800_C)

Sandstone_1000_C=timedata('Sandstone_1000_C')
readlabdat('jun2_12.csv',Sandstone_1000_C)

# %%
# 1 cycle
n_Sandstone_100_1=np.size(Sandstone_100_1.time)
dt_Sandstone_100_1=(Sandstone_100_1.time[2]-Sandstone_100_1.time[1])*1e6
f_Sandstone_100_1=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_100_1,d=dt_Sandstone_100_1))*1000
FT_Sandstone_100_1=np.fft.fftshift(np.fft.fft(Sandstone_100_1.data - np.mean(Sandstone_100_1.data)))

n_Sandstone_300_1=np.size(Sandstone_300_1.time)
dt_Sandstone_300_1=(Sandstone_300_1.time[2]-Sandstone_300_1.time[1])*1e6
f_Sandstone_300_1=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_300_1,d=dt_Sandstone_300_1))*1000
FT_Sandstone_300_1=np.fft.fftshift(np.fft.fft(Sandstone_300_1.data - np.mean(Sandstone_300_1.data)))

n_Sandstone_500_1=np.size(Sandstone_500_1.time)
dt_Sandstone_500_1=(Sandstone_500_1.time[2]-Sandstone_500_1.time[1])*1e6
f_Sandstone_500_1=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_500_1,d=dt_Sandstone_500_1))*1000
FT_Sandstone_500_1=np.fft.fftshift(np.fft.fft(Sandstone_500_1.data - np.mean(Sandstone_500_1.data)))

n_Sandstone_800_1=np.size(Sandstone_800_1.time)
dt_Sandstone_800_1=(Sandstone_800_1.time[2]-Sandstone_800_1.time[1])*1e6
f_Sandstone_800_1=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_800_1,d=dt_Sandstone_800_1))*1000
FT_Sandstone_800_1=np.fft.fftshift(np.fft.fft(Sandstone_800_1.data - np.mean(Sandstone_800_1.data)))

n_Sandstone_1000_1=np.size(Sandstone_1000_1.time)
dt_Sandstone_1000_1=(Sandstone_1000_1.time[2]-Sandstone_1000_1.time[1])*1e6
f_Sandstone_1000_1=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_1000_1,d=dt_Sandstone_1000_1))*1000
FT_Sandstone_1000_1=np.fft.fftshift(np.fft.fft(Sandstone_1000_1.data - np.mean(Sandstone_1000_1.data)))

# 4 cycles
n_Sandstone_100_4=np.size(Sandstone_100_4.time)
dt_Sandstone_100_4=(Sandstone_100_4.time[2]-Sandstone_100_4.time[1])*1e6
f_Sandstone_100_4=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_100_4,d=dt_Sandstone_100_4))*1000
FT_Sandstone_100_4=np.fft.fftshift(np.fft.fft(Sandstone_100_4.data - np.mean(Sandstone_100_4.data)))

n_Sandstone_300_4=np.size(Sandstone_300_4.time)
dt_Sandstone_300_4=(Sandstone_300_4.time[2]-Sandstone_300_4.time[1])*1e6
f_Sandstone_300_4=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_300_4,d=dt_Sandstone_300_4))*1000
FT_Sandstone_300_4=np.fft.fftshift(np.fft.fft(Sandstone_300_4.data - np.mean(Sandstone_300_4.data)))

n_Sandstone_500_4=np.size(Sandstone_500_4.time)
dt_Sandstone_500_4=(Sandstone_500_4.time[2]-Sandstone_500_4.time[1])*1e6
f_Sandstone_500_4=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_500_4,d=dt_Sandstone_500_4))*1000
FT_Sandstone_500_4=np.fft.fftshift(np.fft.fft(Sandstone_500_4.data - np.mean(Sandstone_500_4.data)))

n_Sandstone_800_4=np.size(Sandstone_800_4.time)
dt_Sandstone_800_4=(Sandstone_800_4.time[2]-Sandstone_800_4.time[1])*1e6
f_Sandstone_800_4=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_800_4,d=dt_Sandstone_800_4))*1000
FT_Sandstone_800_4=np.fft.fftshift(np.fft.fft(Sandstone_800_4.data - np.mean(Sandstone_800_4.data)))

n_Sandstone_1000_4=np.size(Sandstone_1000_4.time)
dt_Sandstone_1000_4=(Sandstone_1000_4.time[2]-Sandstone_1000_4.time[1])*1e6
f_Sandstone_1000_4=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_1000_4,d=dt_Sandstone_1000_4))*1000
FT_Sandstone_1000_4=np.fft.fftshift(np.fft.fft(Sandstone_1000_4.data - np.mean(Sandstone_1000_4.data)))

# continous
n_Sandstone_100_C=np.size(Sandstone_100_C.time)
dt_Sandstone_100_C=(Sandstone_100_C.time[2]-Sandstone_100_C.time[1])*1e6
f_Sandstone_100_C=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_100_C,d=dt_Sandstone_100_C))*1000
FT_Sandstone_100_C=np.fft.fftshift(np.fft.fft(Sandstone_100_C.data - np.mean(Sandstone_100_C.data)))

n_Sandstone_300_C=np.size(Sandstone_300_C.time)
dt_Sandstone_300_C=(Sandstone_300_C.time[2]-Sandstone_300_C.time[1])*1e6
f_Sandstone_300_C=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_300_C,d=dt_Sandstone_300_C))*1000
FT_Sandstone_300_C=np.fft.fftshift(np.fft.fft(Sandstone_300_C.data - np.mean(Sandstone_300_C.data)))

n_Sandstone_500_C=np.size(Sandstone_500_C.time)
dt_Sandstone_500_C=(Sandstone_500_C.time[2]-Sandstone_500_C.time[1])*1e6
f_Sandstone_500_C=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_500_C,d=dt_Sandstone_500_C))*1000
FT_Sandstone_500_C=np.fft.fftshift(np.fft.fft(Sandstone_500_C.data - np.mean(Sandstone_500_C.data)))

n_Sandstone_800_C=np.size(Sandstone_800_C.time)
dt_Sandstone_800_C=(Sandstone_800_C.time[2]-Sandstone_800_C.time[1])*1e6
f_Sandstone_800_C=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_800_C,d=dt_Sandstone_800_C))*1000
FT_Sandstone_800_C=np.fft.fftshift(np.fft.fft(Sandstone_800_C.data - np.mean(Sandstone_800_C.data)))

n_Sandstone_1000_C=np.size(Sandstone_1000_C.time)
dt_Sandstone_1000_C=(Sandstone_1000_C.time[2]-Sandstone_1000_C.time[1])*1e6
f_Sandstone_1000_C=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_1000_C,d=dt_Sandstone_1000_C))*1000
FT_Sandstone_1000_C=np.fft.fftshift(np.fft.fft(Sandstone_1000_C.data - np.mean(Sandstone_1000_C.data)))

# %%
plt.plot(f_Sandstone_100_1,np.abs(FT_Sandstone_100_1), label="100 kHz")
plt.plot(f_Sandstone_300_1,np.abs(FT_Sandstone_300_1), label="300 kHz")
plt.plot(f_Sandstone_500_1,np.abs(FT_Sandstone_500_1), label="500 kHz")
plt.plot(f_Sandstone_800_1,np.abs(FT_Sandstone_800_1), label="800 kHz")
plt.plot(f_Sandstone_1000_1,np.abs(FT_Sandstone_1000_1), label="1 MHz")

plt.xlim([0,1300])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Sandstone FFT - 1 Cycle')
plt.savefig("SandstoneFFT_1cycle.png",dpi=300)

# %%
plt.plot(f_Sandstone_100_4,np.abs(FT_Sandstone_100_4), label="100 kHz")
plt.plot(f_Sandstone_300_4,np.abs(FT_Sandstone_300_4), label="300 kHz")
plt.plot(f_Sandstone_500_4,np.abs(FT_Sandstone_500_4), label="500 kHz")
plt.plot(f_Sandstone_800_4,np.abs(FT_Sandstone_800_4), label="800 kHz")
plt.plot(f_Sandstone_1000_4,np.abs(FT_Sandstone_1000_4), label="1 MHz")

plt.xlim([0,1300])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Sandstone FFT - 4 Cycles')
plt.savefig("SandstoneFFT_4cycles.png",dpi=300)

# %%
plt.plot(f_Sandstone_100_C,np.abs(FT_Sandstone_100_C), label="100 kHz")
plt.plot(f_Sandstone_300_C,np.abs(FT_Sandstone_300_C), label="300 kHz")
plt.plot(f_Sandstone_500_C,np.abs(FT_Sandstone_500_C), label="500 kHz")
plt.plot(f_Sandstone_800_C,np.abs(FT_Sandstone_800_C), label="800 kHz")
plt.plot(f_Sandstone_1000_C,np.abs(FT_Sandstone_1000_C), label="1 MHz")

plt.xlim([0,1300])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Sandstone FFT - Continuous')
plt.savefig("SandstoneFFT_cont.png",dpi=300)

# %%
max_C = np.max(np.abs(FT_Sandstone_500_C)) # found visually from FFT_plots notebook
max_4 = np.max(np.abs(FT_Sandstone_100_4)) # found visually from FFT_plots notebook
max_1 = np.max(np.abs(FT_Sandstone_100_1)) # found visually from FFT_plots notebook

max_100C = np.max(np.abs(FT_Sandstone_100_C)/max_C)
max_300C = np.max(np.abs(FT_Sandstone_300_C)/max_C)
max_500C = np.max(np.abs(FT_Sandstone_500_C)/max_C)
max_800C = np.max(np.abs(FT_Sandstone_800_C)/max_C)
max_1000C = np.max(np.abs(FT_Sandstone_1000_C)/max_C)

max_1004 = np.max(np.abs(FT_Sandstone_100_4)/max_4)
max_3004 = np.max(np.abs(FT_Sandstone_300_4)/max_4)
max_5004 = np.max(np.abs(FT_Sandstone_500_4)/max_4)
max_8004 = np.max(np.abs(FT_Sandstone_800_4)/max_4)
max_10004 = np.max(np.abs(FT_Sandstone_1000_4)/max_4)

max_1001 = np.max(np.abs(FT_Sandstone_100_1)/max_1)
max_3001 = np.max(np.abs(FT_Sandstone_300_1)/max_1)
max_5001 = np.max(np.abs(FT_Sandstone_500_1)/max_1)
max_8001 = np.max(np.abs(FT_Sandstone_800_1)/max_1)
max_10001 = np.max(np.abs(FT_Sandstone_1000_1)/max_1)

# %%
amplitudes_C = [max_100C,max_300C,max_500C,max_800C,max_1000C]
amplitudes_4 = [max_1004,max_3004,max_5004,max_8004,max_10004]
amplitudes_1 = [max_1001,max_3001,max_5001,max_8001,max_10001]
freqs = [100,300,500,800,1000] 


plt.figure(2)
plt.plot(freqs,amplitudes_C, label="Continous")
plt.plot(freqs,amplitudes_4, label="4 Cycles")
plt.plot(freqs,amplitudes_1, label="1 Cycle")
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Amplitude')
plt.title('FFT Amplitude vs Frequency - Sandstone (Normalized to Max)')
plt.savefig("Amp_vsFreq_Sandstone.png",dpi=300)

# %%
#plt.plot(Sandstone_1000_1.time*1e6,Sandstone_1000_4.data,label="1 cycle")
#plt.plot(Sandstone_1000_4.time*1e6,Sandstone_1000_4.data,label="4 cycles")
plt.plot(Sandstone_1000_C.time*1e6,Sandstone_1000_C.data,label="continuous")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
#plt.xlim(-10,20)
plt.title('Sandstone - 1 MHz')
# Out:
# Text(0.5, 1.0, 'Sandstone - 1 MHz')

# %%
max1=np.argmax(np.abs(FT_Aluminium_100LC))
max3=np.argmax(np.abs(FT_Aluminium_300LC))
max5=np.argmax(np.abs(FT_Aluminium_500LC))
max8=np.argmax(np.abs(FT_Aluminium_800LC))
max10=np.argmax(np.abs(FT_Aluminium_1000LC))

shift100 = np.abs(100 - np.abs(f_Aluminium_100LC[max1]))
shift300 = np.abs(300 - np.abs(f_Aluminium_300LC[max3]))
shift500 = np.abs(500 - np.abs(f_Aluminium_500LC[max5]))
shift800 = np.abs(800 - np.abs(f_Aluminium_800LC[max8]))
shift1000 = np.abs(1000 - np.abs(f_Aluminium_1000LC[max10]))

# %%
freqs = [100,300,500,800,1000] 
shifts = [shift100,shift300,shift500,shift800,shift1000]

plt.plot(freqs,shifts,'-o')

#plt.xlim([-100,1500])
#plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Absolute Shift (kHz)')
plt.title('Frequency Shift - Aluminium (Continuous)')
plt.savefig("AluminiumFreqShift.jpg",dpi=300)

# %%
slope, intercept = np.polyfit(freqs,shifts,1)

# %%
slope
# Out:
# 2.4330479151869537e-14

# %%
f_Aluminium_100LC[2]-f_Aluminium_100LC[1]
# Out:
# 10.0

# %%
f_Aluminium_1000LC[5]-f_Aluminium_1000LC[4]
# Out:
# 10.0
