# %%
exec(open('ComputeDelays.py').read())

p12_100=timedata('p12_100')
readlabdat('jun24_11.csv',p12_100)
p12_300=timedata('p12_300')
readlabdat('jun24_12.csv',p12_300)
p12_500=timedata('p12_500')
readlabdat('jun24_13.csv',p12_500)
p12_800=timedata('p12_800')
readlabdat('jun24_14.csv',p12_800)
p12_1000=timedata('p12_1000')
readlabdat('jun24_15.csv',p12_1000)

p35_100=timedata('p35_100')
readlabdat('jun24_16.csv',p35_100)
p35_300=timedata('p35_300')
readlabdat('jun24_17.csv',p35_300)
p35_500=timedata('p35_500')
readlabdat('jun24_18.csv',p35_500)
p35_800=timedata('p35_800')
readlabdat('jun24_19.csv',p35_800)
p35_1000=timedata('p35_1000')
readlabdat('jun24_20.csv',p35_1000)

# %%
plt.plot(p12_100.time*1e6,p12_100.data,label="P12")
plt.plot(p35_100.time*1e6,p35_100.data,label="P35")
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample - 100 kHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample - 100 kHz')

# %%
p12_amps = [np.max(p12_100.data),np.max(p12_300.data),np.max(p12_500.data),np.max(p12_800.data),np.max(p12_1000.data)]
p35_amps = [np.max(p35_100.data),np.max(p35_300.data),np.max(p35_500.data),np.max(p35_800.data),np.max(p35_1000.data)]
freqs = [100,300,500,800,1000] 

plt.plot(freqs,p12_amps, label="P12")
plt.plot(freqs,p35_amps, label="P35")
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Amplitude (V)')
plt.title('Max Amplitude vs Frequency - No Sample - 100 kHz')
# Out:
# Text(0.5, 1.0, 'Max Amplitude vs Frequency - No Sample - 100 kHz')

# %%
plt.plot(p12_800.time*1e6,p12_800.data,label="P12")
#plt.plot(p35_100.time*1e6,p35_100.data,label="P35")
#plt.legend()
plt.xlim([0,5])
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample - 100 kHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample - 100 kHz')

# %% [markdown]
# # Understanding FFT sampling

# %%
exec(open('ComputeDelays.py').read())

GS_1=timedata('GS_1')
readlabdat('jul18_1.csv',GS_1)

GS_2=timedata('GS_2')
readlabdat('jul18_2.csv',GS_2)

GS_3=timedata('GS_3')
readlabdat('jul18_3.csv',GS_3)

GS_4=timedata('GS_4')
readlabdat('jul18_4.csv',GS_4)

GS_5=timedata('GS_5')
readlabdat('jul18_5.csv',GS_5)

GS_6=timedata('GS_6')
readlabdat('jul18_6.csv',GS_6)

GS_7=timedata('GS_7')
readlabdat('jul18_7.csv',GS_7)

GS_8=timedata('GS_8')
readlabdat('jul18_8.csv',GS_8)

# %%
# FFT



# 500 ns
n_GS_2=np.size(GS_2.time)
dt_GS_2=(GS_2.time[2]-GS_2.time[1])*1e6
f_GS_2=np.fft.fftshift(np.fft.fftfreq(n_GS_2,d=dt_GS_2))*1000
FT_GS_2=np.fft.fftshift(np.fft.fft(GS_2.data - np.mean(GS_2.data)))
df_2 = f_GS_2[2]-f_GS_2[1]

# 1 us
n_GS_3=np.size(GS_3.time)
dt_GS_3=(GS_3.time[2]-GS_3.time[1])*1e6
f_GS_3=np.fft.fftshift(np.fft.fftfreq(n_GS_3,d=dt_GS_3))*1000
FT_GS_3=np.fft.fftshift(np.fft.fft(GS_3.data - np.mean(GS_3.data)))
df_3 = f_GS_3[2]-f_GS_3[1]

# 2 us
n_GS_4=np.size(GS_4.time)
dt_GS_4=(GS_4.time[2]-GS_4.time[1])*1e6
f_GS_4=np.fft.fftshift(np.fft.fftfreq(n_GS_4,d=dt_GS_4))*1000
FT_GS_4=np.fft.fftshift(np.fft.fft(GS_4.data - np.mean(GS_4.data)))
df_4 = f_GS_4[2]-f_GS_4[1]

# 5 us
n_GS_5=np.size(GS_5.time)
dt_GS_5=(GS_5.time[2]-GS_5.time[1])*1e6
f_GS_5=np.fft.fftshift(np.fft.fftfreq(n_GS_5,d=dt_GS_5))*1000
FT_GS_5=np.fft.fftshift(np.fft.fft(GS_5.data - np.mean(GS_5.data)))
df_5 = f_GS_5[2]-f_GS_5[1]

# 10 us
n_GS_6=np.size(GS_6.time)
dt_GS_6=(GS_6.time[2]-GS_6.time[1])*1e6
f_GS_6=np.fft.fftshift(np.fft.fftfreq(n_GS_6,d=dt_GS_6))*1000
FT_GS_6=np.fft.fftshift(np.fft.fft(GS_6.data - np.mean(GS_6.data)))
df_6 = f_GS_6[2]-f_GS_6[1]

# 20 us
n_GS_7=np.size(GS_7.time)
dt_GS_7=(GS_7.time[2]-GS_7.time[1])*1e6
f_GS_7=np.fft.fftshift(np.fft.fftfreq(n_GS_7,d=dt_GS_7))*1000
FT_GS_7=np.fft.fftshift(np.fft.fft(GS_7.data - np.mean(GS_7.data)))
df_7 = f_GS_7[2]-f_GS_7[1]

# 50 us
n_GS_8=np.size(GS_8.time)
dt_GS_8=(GS_8.time[2]-GS_8.time[1])*1e6
f_GS_8=np.fft.fftshift(np.fft.fftfreq(n_GS_8,d=dt_GS_8))*1000
FT_GS_8=np.fft.fftshift(np.fft.fft(GS_8.data - np.mean(GS_8.data)))
df_8 = f_GS_8[2]-f_GS_8[1]

# %%
# 200 ns
n_GS_1=np.size(GS_1.time)
dt_GS_1=(GS_1.time[2]-GS_1.time[1])*1e6
f_GS_1=np.fft.fftshift(np.fft.fftfreq(n_GS_1,d=dt_GS_1))*1000
FT_GS_1=np.fft.fftshift(np.fft.fft(GS_1.data - np.mean(GS_1.data)))
df_1 = f_GS_1[2]-f_GS_1[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12264/3589123828.py in <module>
#       1 # 200 ns
#       2 n_GS_1=np.size(GS_1.time)
# ----> 3 dt_GS_1=(GS_1.time[2]-GS_1.time[1])*1e6
#       4 f_GS_1=np.fft.fftshift(np.fft.fftfreq(n_GS_1,d=dt_GS_1))*1000
#       5 FT_GS_1=np.fft.fftshift(np.fft.fft(GS_1.data - np.mean(GS_1.data)))
#
# IndexError: index 2 is out of bounds for axis 0 with size 0

# %%
scale = [5,10,20,50,100,200,500]
df = [df_2,df_3,df_4,df_5,df_6,df_7,df_8]

plt.plot(scale, df,'--',label="Fit")
plt.plot(scale, df,'o',label="Data")
plt.legend()
plt.text(300, 55, '$y=1000/x$', fontsize=10)
plt.text(300, 40, '$R^2=1$', fontsize=10)
plt.xlabel('Total Time, T ($\mu$s)') #$\mu$
plt.ylabel('Frequency Sampling, $df$   (kHz)')
plt.title('Frequency and Time Sampling')
#plt.savefig("Figures/Time_Freq_Sampling.jpg",dpi=400)
# Out:
# Text(0.5, 1.0, 'Frequency and Time Sampling')

# %%
scale = [5/1e6,10/1e6,20/1e6,50/1e6,100/1e6,200/1e6,500/1e6]
df = [df_2*1000,df_3*1000,df_4*1000,df_5*1000,df_6*1000,df_7*1000,df_8*1000]

plt.plot(scale, df,'--',label="Fit")
plt.plot(scale, df,'o',label="Data")
plt.legend()
plt.text(0.0003, 45000, '$y=1/x$', fontsize=10)
plt.text(0.0003, 30000, '$R^2=1$', fontsize=10)
plt.xlabel('Total Time, T (s)') #$\mu$
plt.ylabel('Frequency Sampling, $df$   (Hz)')
plt.ticklabel_format(style='sci', axis='x', scilimits=(3,5))
plt.ticklabel_format(style='sci', axis='y', scilimits=(4,4))
plt.title('Frequency and Time Sampling')
plt.savefig("Figures/Time_Freq_Sampling.jpg",dpi=400)

# %%
T = GS_2.time[-1] + abs(GS_2.time[0])
print(T*1e6)
# Out:
# 4.9975

# %%
T = GS_3.time[-1] + abs(GS_3.time[0])
print(T*1e6)
# Out:
# 9.995

# %%
T = GS_4.time[-1] + abs(GS_4.time[0])
print(T*1e6)
# Out:
# 19.99

# %%
T = GS_5.time[-1] + abs(GS_5.time[0])
print(T*1e6)
# Out:
# 49.975

# %%
T = GS_6.time[-1] + abs(GS_6.time[0])
print(T*1e6)
# Out:
# 99.95

# %%
T = GS_7.time[-1] + abs(GS_7.time[0])
print(T*1e6)
# Out:
# 199.9

# %%
T = GS_8.time[-1] + abs(GS_8.time[0])
print(T*1e6)
# Out:
# 499.75

# %%
df
# Out:
# [200.0, 100.0, 50.0, 20.0, 10.0, 5.0, 1.9999999999997726]

# %%
time_scale = 10 # us, per pixel on scope
df = 100/time_scale

# %% [markdown]
# # compare raw data and FFT of every material - 100 khz

# %%
exec(open('ComputeDelays.py').read())

NoSample_100=timedata('NoSample_100')
readlabdat('may16_1.csv',NoSample_100)

transducer_100=timedata('transducer_100')
readlabdat('apr27_21.csv',transducer_100)

Aluminium_100=timedata('Aluminium_100')
readlabdat('jun2_3.csv',Aluminium_100)

Sandstone_100=timedata('Sandstone_100')
readlabdat('jun2_8.csv',Sandstone_100)

Delrin_100=timedata('Delrin_100')
readlabdat('jun2_13.csv',Delrin_100)

Acrylic_100=timedata('Acrylic_100')
readlabdat('jun2_18.csv',Acrylic_100)

Bedding_100=timedata('Bedding_100')
readlabdat('jun2_23.csv', Bedding_100)

tofuC_100=timedata('tofuC_100')
readlabdat('jul13_1.csv',tofuC_100)

#plt.plot(NoSample_100.time*1e6,NoSample_100.data,label="No Sample - Gen to Osc")
#plt.plot(transducer_100.time*1e6,transducer_100.data,label="No Sample")
plt.plot(Aluminium_100.time*1e6,Aluminium_100.data,label="Aluminium")
plt.plot(Sandstone_100.time*1e6,Sandstone_100.data,label="Sandstone (A)")
plt.plot(Delrin_100.time*1e6,Delrin_100.data,label="Delrin")
plt.plot(Acrylic_100.time*1e6,Acrylic_100.data,label="Acrylic")
plt.plot(Bedding_100.time*1e6,Bedding_100.data,label="Sandstone (B)")
#plt.plot(tofuC_100.time*1e6,tofuC_100.data,label="Tofu")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 100 kHz')
plt.savefig("compare_materials_100khz.png",dpi=300)

# %%
n_tofuC_100=np.size(tofuC_100.time)
dt_tofuC_100=(tofuC_100.time[2]-tofuC_100.time[1])*1e6
f_tofuC_100=np.fft.fftshift(np.fft.fftfreq(n_tofuC_100,d=dt_tofuC_100))*1000
FT_tofuC_100=np.fft.fftshift(np.fft.fft(tofuC_100.data - np.mean(tofuC_100.data)))

n_Bedding_100=np.size(Bedding_100.time)
dt_Bedding_100=(Bedding_100.time[2]-Bedding_100.time[1])*1e6
f_Bedding_100=np.fft.fftshift(np.fft.fftfreq(n_Bedding_100,d=dt_Bedding_100))*1000
FT_Bedding_100=np.fft.fftshift(np.fft.fft(Bedding_100.data - np.mean(Bedding_100.data)))

n_Acrylic_100=np.size(Acrylic_100.time)
dt_Acrylic_100=(Acrylic_100.time[2]-Acrylic_100.time[1])*1e6
f_Acrylic_100=np.fft.fftshift(np.fft.fftfreq(n_Acrylic_100,d=dt_Acrylic_100))*1000
FT_Acrylic_100=np.fft.fftshift(np.fft.fft(Acrylic_100.data - np.mean(Acrylic_100.data)))

n_Delrin_100=np.size(Delrin_100.time)
dt_Delrin_100=(Delrin_100.time[2]-Delrin_100.time[1])*1e6
f_Delrin_100=np.fft.fftshift(np.fft.fftfreq(n_Delrin_100,d=dt_Delrin_100))*1000
FT_Delrin_100=np.fft.fftshift(np.fft.fft(Delrin_100.data - np.mean(Delrin_100.data)))

n_Sandstone_100=np.size(Sandstone_100.time)
dt_Sandstone_100=(Sandstone_100.time[2]-Sandstone_100.time[1])*1e6
f_Sandstone_100=np.fft.fftshift(np.fft.fftfreq(n_Sandstone_100,d=dt_Sandstone_100))*1000
FT_Sandstone_100=np.fft.fftshift(np.fft.fft(Sandstone_100.data - np.mean(Sandstone_100.data)))

n_Aluminium_100=np.size(Aluminium_100.time)
dt_Aluminium_100=(Aluminium_100.time[2]-Aluminium_100.time[1])*1e6
f_Aluminium_100=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_100,d=dt_Aluminium_100))*1000
FT_Aluminium_100=np.fft.fftshift(np.fft.fft(Aluminium_100.data - np.mean(Aluminium_100.data)))


plt.plot(f_Aluminium_100,np.abs(FT_Aluminium_100), label="Aluminium")
plt.plot(f_Sandstone_100,np.abs(FT_Sandstone_100), label="Sandstone (A)")
plt.plot(f_Delrin_100,np.abs(FT_Delrin_100), label="Delrin")
plt.plot(f_Acrylic_100,np.abs(FT_Acrylic_100), label="Acrylic")
plt.plot(f_Bedding_100,np.abs(FT_Bedding_100), label="Sandstone (B)")
#plt.plot(f_tofuC_100,np.abs(FT_tofuC_100), label="Tofu")
plt.xlim([-0,200])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('FFT Material Comparison - 100 kHz')
plt.savefig("FFTcompare_materials_100khz.png",dpi=300)

# %%
lst = np.linspace(1,100,100)

def decimate(lst):
    lst = lst[::10]
    return lst

# %%
y_decimated = decimate(lst)

# %%
y_decimated
# Out:
# array([ 1., 11., 21., 31., 41., 51., 61., 71., 81., 91.])

# %%
lst[-1]
# Out:
# 100.0
