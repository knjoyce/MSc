# %%
exec(open('ComputeDelays.py').read())
from myfft import myfft

Cwc_100=timedata('Cwc_100')
readlabdat('dec13_0.csv',Cwc_100)
Cwc_200=timedata('Cwc_200')
readlabdat('dec13_1.csv',Cwc_200)
Cwc_300=timedata('Cwc_300')
readlabdat('dec13_2.csv',Cwc_300)
Cwc_400=timedata('Cwc_400')
readlabdat('dec13_3.csv',Cwc_400)
Cwc_500=timedata('Cwc_500')
readlabdat('dec13_4.csv',Cwc_500)
Cwc_600=timedata('Cwc_600')
readlabdat('dec13_5.csv',Cwc_600)
Cwc_700=timedata('Cwc_70')
readlabdat('dec13_6.csv',Cwc_700)

# %%
import matplotlib.pyplot as plt

f1,FT1=myfft(Cwc_100.time,Cwc_100.data)
f2,FT2=myfft(Cwc_200.time,Cwc_200.data)
f3,FT3=myfft(Cwc_300.time,Cwc_300.data)
f4,FT4=myfft(Cwc_400.time,Cwc_400.data)
f5,FT5=myfft(Cwc_500.time,Cwc_500.data)
f6,FT6=myfft(Cwc_600.time,Cwc_600.data)
f7,FT7=myfft(Cwc_700.time,Cwc_700.data)


plt.title('1) Cement w/ Cu wires, S-wave probe, O1')
plt.plot(f1,np.abs(FT1)/max(np.abs(FT1)),label='100 kHz')
plt.plot(f2,np.abs(FT2)/max(np.abs(FT2)),label='200 kHz')
plt.plot(f3,np.abs(FT3)/max(np.abs(FT3)),label='300 kHz')
plt.plot(f4,np.abs(FT4)/max(np.abs(FT4)),label='400 kHz')
plt.plot(f5,np.abs(FT5)/max(np.abs(FT5)),label='500 kHz')
plt.plot(f6,np.abs(FT6)/max(np.abs(FT6)),label='600 kHz')
plt.plot(f7,np.abs(FT7)/max(np.abs(FT7)),label='700 kHz')

plt.xlim([-100,1500])
plt.legend()
plt.ylabel('Intensity')
plt.xlabel('Frequency (kHz)')
# Out:
# Text(0.5, 0, 'Frequency (kHz)')

# %%
Cwc2_100=timedata('Cwc2_100')
readlabdat('dec13_7.csv',Cwc2_100)
Cwc2_200=timedata('Cwc2_200')
readlabdat('dec13_8.csv',Cwc2_200)
Cwc2_300=timedata('Cwc2_300')
readlabdat('dec13_9.csv',Cwc2_300)
Cwc2_400=timedata('Cwc2_400')
readlabdat('dec13_10.csv',Cwc2_400)
Cwc2_500=timedata('Cwc2_500')
readlabdat('dec13_11.csv',Cwc2_500)
Cwc2_600=timedata('Cwc2_600')
readlabdat('dec13_12.csv',Cwc2_600)
Cwc2_700=timedata('Cwc2_700')
readlabdat('dec13_13.csv',Cwc2_700)

f1,FT1=myfft(Cwc2_100.time,Cwc2_100.data)
f2,FT2=myfft(Cwc2_200.time,Cwc2_200.data)
f3,FT3=myfft(Cwc2_300.time,Cwc2_300.data)
f4,FT4=myfft(Cwc2_400.time,Cwc2_400.data)
f5,FT5=myfft(Cwc2_500.time,Cwc2_500.data)
f6,FT6=myfft(Cwc2_600.time,Cwc2_600.data)
f7,FT7=myfft(Cwc2_700.time,Cwc2_700.data)

# try to improve 700 kHz fft by zooming in on wave 
f8,FT8=myfft(Cwc2_700.time[900:1000],Cwc2_700.data[900:1000])


plt.title('2) Cement w/ Cu wires, S-wave probe, O2')
plt.plot(f1,np.abs(FT1)/max(np.abs(FT1)),label='100 kHz')
plt.plot(f2,np.abs(FT2)/max(np.abs(FT2)),label='200 kHz')
plt.plot(f3,np.abs(FT3)/max(np.abs(FT3)),label='300 kHz')
plt.plot(f4,np.abs(FT4)/max(np.abs(FT4)),label='400 kHz')
plt.plot(f5,np.abs(FT5)/max(np.abs(FT5)),label='500 kHz')
plt.plot(f6,np.abs(FT6)/max(np.abs(FT6)),label='600 kHz')
plt.plot(f7,np.abs(FT7)/max(np.abs(FT7)),label='700 kHz')
#plt.plot(f8,np.abs(FT8)/max(np.abs(FT8)),label='700 kHz')

plt.xlim([-100,1500])
plt.legend()
plt.ylabel('Intensity')
plt.xlabel('Frequency (kHz)')
# Out:
# Text(0.5, 0, 'Frequency (kHz)')

# %%
plt.plot(Cwc2_700.time[895:1010],Cwc2_700.data[895:1010])

# %%
plt.plot(f8,np.abs(FT8)/max(np.abs(FT8)),label='700 kHz')

# %%
Cwc3_100=timedata('Cwc3_100')
readlabdat('dec16_0.csv',Cwc3_100)
Cwc3_200=timedata('Cwc3_200')
readlabdat('dec16_1.csv',Cwc3_200)
Cwc3_300=timedata('Cwc3_300')
readlabdat('dec16_2.csv',Cwc3_300)
Cwc3_400=timedata('Cwc3_400')
readlabdat('dec16_3.csv',Cwc3_400)
Cwc3_500=timedata('Cwc3_500')
readlabdat('dec16_4.csv',Cwc3_500)
Cwc3_600=timedata('Cwc3_600')
readlabdat('dec16_5.csv',Cwc3_600)
Cwc3_700=timedata('Cwc3_700')
readlabdat('dec16_6.csv',Cwc3_700)

f1,FT1=myfft(Cwc3_100.time,Cwc3_100.data)
f2,FT2=myfft(Cwc3_200.time,Cwc3_200.data)
f3,FT3=myfft(Cwc3_300.time,Cwc3_300.data)
f4,FT4=myfft(Cwc3_400.time,Cwc3_400.data)
f5,FT5=myfft(Cwc3_500.time,Cwc3_500.data)
f6,FT6=myfft(Cwc3_600.time,Cwc3_600.data)
f7,FT7=myfft(Cwc3_700.time,Cwc3_700.data)

plt.title('3) Cement w/ Cu wires, S-wave probe, O3')
plt.plot(f1,np.abs(FT1),label='100 kHz')
plt.plot(f2,np.abs(FT2),label='200 kHz')
plt.plot(f3,np.abs(FT3),label='300 kHz')
plt.plot(f4,np.abs(FT4),label='400 kHz')
plt.plot(f5,np.abs(FT5),label='500 kHz')
plt.plot(f6,np.abs(FT6),label='600 kHz')
plt.plot(f7,np.abs(FT7),label='700 kHz')

plt.xlim([0,800])
plt.legend()
plt.ylabel('Intensity')
plt.xlabel('Frequency (kHz)')
# Out:
# Text(0.5, 0, 'Frequency (kHz)')

# %%
Cwc4_100=timedata('Cwc4_100')
readlabdat('dec16_7.csv',Cwc4_100)
Cwc4_200=timedata('Cwc4_200')
readlabdat('dec16_8.csv',Cwc4_200)
Cwc4_300=timedata('Cwc4_300')
readlabdat('dec16_9.csv',Cwc4_300)
Cwc4_400=timedata('Cwc4_400')
readlabdat('dec16_10.csv',Cwc4_400)
Cwc4_500=timedata('Cwc4_500')
readlabdat('dec16_11.csv',Cwc4_500)
Cwc4_600=timedata('Cwc4_600')
readlabdat('dec16_12.csv',Cwc4_600)
Cwc4_700=timedata('Cwc4_700')
readlabdat('dec16_13.csv',Cwc4_700)

f1,FT1=myfft(Cwc4_100.time,Cwc4_100.data)
f2,FT2=myfft(Cwc4_200.time,Cwc4_200.data)
f3,FT3=myfft(Cwc4_300.time,Cwc4_300.data)
f4,FT4=myfft(Cwc4_400.time,Cwc4_400.data)
f5,FT5=myfft(Cwc4_500.time,Cwc4_500.data)
f6,FT6=myfft(Cwc4_600.time,Cwc4_600.data)
f7,FT7=myfft(Cwc4_700.time,Cwc4_700.data)

plt.title('4) Cement w/ Cu wires, S-wave probe, O4')
plt.plot(f1,np.abs(FT1),label='100 kHz')
plt.plot(f2,np.abs(FT2),label='200 kHz')
plt.plot(f3,np.abs(FT3),label='300 kHz')
plt.plot(f4,np.abs(FT4),label='400 kHz')
plt.plot(f5,np.abs(FT5),label='500 kHz')
plt.plot(f6,np.abs(FT6),label='600 kHz')
plt.plot(f7,np.abs(FT7),label='700 kHz')

plt.xlim([0,800])
plt.legend()
plt.ylabel('Intensity')
plt.xlabel('Frequency (kHz)')
# Out:
# Text(0.5, 0, 'Frequency (kHz)')

# %% [markdown]
# # Redo O2 Experiment - Feb 8

# %% [markdown]
# Plot 2 above, shows a strange frequency spectrum for 700 kHz. This is the first indication of a spectrum not matching the input frequency.
#
# Since learning that Jacob tracked the P-wave part of the probe (S-wave transducers), I collected new data and tracked the P-wave part as well. The data I collected previously on Dec 13th was before I knew about S-wave transducers producing P-waves and S-waves.
#
# Re-did in notebook: Cement_Cu_5mm
