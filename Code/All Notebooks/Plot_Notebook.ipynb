# %% [markdown]
# # P-Wave Transducer Comparisons - No Honey, No Sample - 100 kHz

# %%
exec(open('ComputeDelays.py').read())

# 100 Hz
p12_100=timedata('p12_100')
readlabdat('apr27_1.csv',p12_100)
p34_100=timedata('p34_100')
readlabdat('apr27_6.csv',p34_100)
p56_100=timedata('p56_100')
readlabdat('apr27_11.csv',p56_100)
s12_100=timedata('s12_100')
readlabdat('apr27_16.csv',s12_100)

plt.figure(1)
plt.plot(p12_100.time*1e6,p12_100.data,label="P12")
plt.plot(p34_100.time*1e6,p34_100.data,label="P34")
plt.plot(p56_100.time*1e6,p56_100.data,label="P56")
#plt.plot(s12_100.time*1e6,s12_100.data,label="S12")

plt.legend()
plt.xlabel('Time ($\mu$s)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample, No Couplant - 100 kHz')
plt.savefig("transducer_compare_noHoney.jpeg", dpi=300)

# %% [markdown]
# # P-Wave Transducer Comparisons - No Honey, No Sample - 300 kHz

# %%
# 300 Hz
p12_300=timedata('p12_300')
readlabdat('apr27_2.csv',p12_300)
p34_300=timedata('p34_300')
readlabdat('apr27_7.csv',p34_300)
p56_300=timedata('p56_300')
readlabdat('apr27_12.csv',p56_300)
s12_300=timedata('s12_300')
readlabdat('apr27_17.csv',s12_300)

plt.figure(2)
plt.plot(p12_300.time*1e6,p12_300.data,label="P12")
plt.plot(p34_300.time*1e6,p34_300.data,label="P34")
plt.plot(p56_300.time*1e6,p56_300.data,label="P56")
#plt.plot(s12_300.time*1e6,s12_300.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample, No Couplant - 300 kHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample, No Couplant - 300 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - No Honey, No Sample - 500 kHz

# %%
# 500 Hz
p12_500=timedata('p12_500')
readlabdat('apr27_3.csv',p12_500)
p34_500=timedata('p34_500')
readlabdat('apr27_8.csv',p34_500)
p56_500=timedata('p56_500')
readlabdat('apr27_13.csv',p56_500)
s12_500=timedata('s12_500')
readlabdat('apr27_18.csv',s12_500)

plt.figure(3)
plt.plot(p12_500.time*1e6,p12_500.data,label="P12")
plt.plot(p34_500.time*1e6,p34_500.data,label="P34")
plt.plot(p56_500.time*1e6,p56_500.data,label="P56")
#plt.plot(s12_500.time*1e6,s12_500.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample, No Couplant - 500 kHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample, No Couplant - 500 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - No Honey, No Sample - 800 kHz

# %%
# 800 Hz
p12_800=timedata('p12_800')
readlabdat('apr27_4.csv',p12_800)
p34_800=timedata('p34_800')
readlabdat('apr27_9.csv',p34_800)
p56_800=timedata('p56_800')
readlabdat('apr27_14.csv',p56_800)
s12_800=timedata('s12_800')
readlabdat('apr27_19.csv',s12_800)

plt.figure(4)
plt.plot(p12_800.time*1e6,p12_800.data,label="P12")
plt.plot(p34_800.time*1e6,p34_800.data,label="P34")
plt.plot(p56_800.time*1e6,p56_800.data,label="P56")
#plt.plot(s12_800.time*1e6,s12_800.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample, No Couplant - 800 kHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample, No Couplant - 800 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - No Honey, No Sample - 1 MHz

# %%
# 1 MHz
p12_1000=timedata('p12_1000')
readlabdat('apr27_5.csv',p12_1000)
p34_1000=timedata('p34_1000')
readlabdat('apr27_10.csv',p34_1000)
p56_1000=timedata('p56_1000')
readlabdat('apr27_15.csv',p56_1000)
s12_1000=timedata('s12_1000')
readlabdat('apr27_20.csv',s12_1000)

plt.figure(5)
plt.plot(p12_1000.time*1e6,p12_1000.data,label="P12")
plt.plot(p34_1000.time*1e6,p34_1000.data,label="P34")
plt.plot(p56_1000.time*1e6,p56_1000.data,label="P56")
#plt.plot(s12_1000.time*1e6,s12_1000.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Transducer Pair Comparisons - No Sample, No Couplant - 1 MHz')
# Out:
# Text(0.5, 1.0, 'Transducer Pair Comparisons - No Sample, No Couplant - 1 MHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - Honey, No Sample - 100 kHz

# %%
exec(open('ComputeDelays.py').read())

# 100 Hz
p12_100_h=timedata('p12_100_h')
readlabdat('apr27_21.csv',p12_100_h)
p34_100_h=timedata('p34_100_h')
readlabdat('apr27_26.csv',p34_100_h)
p56_100_h=timedata('p56_100_h')
readlabdat('apr27_31.csv',p56_100_h)
s12_100_h=timedata('s12_100_h')
readlabdat('apr27_36.csv',s12_100_h)

plt.figure(1)
plt.plot(p12_100_h.time*1e6,p12_100_h.data,label="P12")
plt.plot(p34_100_h.time*1e6,p34_100_h.data,label="P34")
plt.plot(p56_100_h.time*1e6,p56_100_h.data,label="P56")
plt.plot(s12_100_h.time*1e6,s12_100_h.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('P-Wave Transducer Comparisons - Honey, No Sample - 100 kHz')
plt.savefig("HighResoltion.png",dpi=300)

# %% [markdown]
# # P-Wave Transducer Comparisons - Honey, No Sample - 300 kHz

# %%
# 300 Hz
p12_300_h=timedata('p12_300_h')
readlabdat('apr27_22.csv',p12_300_h)
p34_300_h=timedata('p34_300_h')
readlabdat('apr27_27.csv',p34_300_h)
p56_300_h=timedata('p56_300_h')
readlabdat('apr27_32.csv',p56_300_h)
s12_300_h=timedata('s12_300_h')
readlabdat('apr27_37.csv',s12_300_h)

plt.figure(2)
plt.plot(p12_300_h.time*1e6,p12_300_h.data,label="P12")
plt.plot(p34_300_h.time*1e6,p34_300_h.data,label="P34")
plt.plot(p56_300_h.time*1e6,p56_300_h.data,label="P56")
#plt.plot(s12_300_h.time*1e6,s12_300_h.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('P-Wave Transducer Comparisons - Honey, No Sample - 300 kHz')
# Out:
# Text(0.5, 1.0, 'P-Wave Transducer Comparisons - Honey, No Sample - 300 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - Honey, No Sample - 500 kHz

# %%
# 500 Hz
p12_500_h=timedata('p12_500_h')
readlabdat('apr27_23.csv',p12_500_h)
p34_500_h=timedata('p34_500_h')
readlabdat('apr27_28.csv',p34_500_h)
p56_500_h=timedata('p56_500_h')
readlabdat('apr27_33.csv',p56_500_h)
s12_500_h=timedata('s12_500_h')
readlabdat('apr27_38.csv',s12_500_h)

plt.figure(3)
plt.plot(p12_500_h.time*1e6,p12_500_h.data,label="P12")
plt.plot(p34_500_h.time*1e6,p34_500_h.data,label="P34")
plt.plot(p56_500_h.time*1e6,p56_500_h.data,label="P56")
#plt.plot(s12_500_h.time*1e6,s12_500_h.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('P-Wave Transducer Comparisons - Honey, No Sample - 500 kHz')
# Out:
# Text(0.5, 1.0, 'P-Wave Transducer Comparisons - Honey, No Sample - 500 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - Honey, No Sample - 800 kHz

# %%
# 800 Hz
p12_800_h=timedata('p12_800_h')
readlabdat('apr27_24.csv',p12_800_h)
p34_800_h=timedata('p34_800_h')
readlabdat('apr27_29.csv',p34_800_h)
p56_800_h=timedata('p56_800_h')
readlabdat('apr27_34.csv',p56_800_h)
s12_800_h=timedata('s12_800_h')
readlabdat('apr27_39.csv',s12_800_h)

plt.figure(4)
plt.plot(p12_800_h.time*1e6,p12_800_h.data,label="P12")
plt.plot(p34_800_h.time*1e6,p34_800_h.data,label="P34")
plt.plot(p56_800_h.time*1e6,p56_800_h.data,label="P56")
#plt.plot(s12_800_h.time*1e6,s12_800_h.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('P-Wave Transducer Comparisons - Honey, No Sample - 800 kHz')
# Out:
# Text(0.5, 1.0, 'P-Wave Transducer Comparisons - Honey, No Sample - 800 kHz')

# %% [markdown]
# # P-Wave Transducer Comparisons - Honey, No Sample - 1 MHz

# %%
# 1 MHz
p12_1000_h=timedata('p12_1000_h')
readlabdat('apr27_25.csv',p12_1000_h)
p34_1000_h=timedata('p34_1000_h')
readlabdat('apr27_30.csv',p34_1000_h)
p56_1000_h=timedata('p56_1000_h')
readlabdat('apr27_35.csv',p56_1000_h)
s12_1000_h=timedata('s12_1000_h')
readlabdat('apr27_40.csv',s12_1000_h)

plt.figure(5)
plt.plot(p12_1000_h.time*1e6,p12_1000_h.data,label="P12")
plt.plot(p34_1000_h.time*1e6,p34_1000_h.data,label="P34")
plt.plot(p56_1000_h.time*1e6,p56_1000_h.data,label="P56")
#plt.plot(s12_1000_h.time*1e6,s12_1000_h.data,label="S12")

plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('P-Wave Transducer Comparisons - Honey, No Sample - 1 MHz')
# Out:
# Text(0.5, 1.0, 'P-Wave Transducer Comparisons - Honey, No Sample - 1 MHz')

# %% [markdown]
# # Plot showing ym honey is used:

# %% [markdown]
# # Generator to Oscilloscope - 100 kHz

# %%
# 100 kHz
may16_100=timedata('may16_100')
readlabdat('may16_1.csv',may16_100)

plt.plot(may16_100.time*1e6,may16_100.data,label="100 kHz")

plt.legend()
#plt.xlim(0,20)
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Generator to Oscilloscope - 100 kHz')
# Out:
# Text(0.5, 1.0, 'Generator to Oscilloscope - 100 kHz')

# %% [markdown]
# # Generator to Oscilloscope - 300 kHz

# %%
# 300 kHz
may16_300=timedata('may16_300')
readlabdat('may16_2.csv',may16_300)

plt.plot(may16_300.time*1e6,may16_300.data,label="300 kHz")
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Generator to Oscilloscope - 300 kHz')
# Out:
# Text(0.5, 1.0, 'Generator to Oscilloscope - 300 kHz')

# %% [markdown]
# # Generator to Oscilloscope - 500 kHz

# %%
# 500 kHz
may16_500=timedata('may16_500')
readlabdat('may16_3.csv',may16_500)

plt.plot(may16_500.time*1e6,may16_500.data,label="500 kHz")
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Generator to Oscilloscope - 500 kHz')
# Out:
# Text(0.5, 1.0, 'Generator to Oscilloscope - 500 kHz')

# %% [markdown]
# # Generator to Oscilloscope - 800 kHz

# %%
# 800 kHz
may16_800=timedata('may16_800')
readlabdat('may16_4.csv',may16_800)

plt.plot(may16_800.time*1e6,may16_800.data,label="800 kHz")
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Generator to Oscilloscope - 800 kHz')
# Out:
# Text(0.5, 1.0, 'Generator to Oscilloscope - 800 kHz')

# %% [markdown]
# # Generator to Oscilloscope - 1 MHz

# %%
# 1 MHz
may16_1000=timedata('may16_1000')
readlabdat('may16_5.csv',may16_1000)

plt.plot(may16_1000.time*1e6,may16_1000.data,label="1 MHz")
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Generator to Oscilloscope')
# Out:
# Text(0.5, 1.0, 'Generator to Oscilloscope')

# %% [markdown]
# # Comparing Materials - 100 kHz

# %%
NoSample_100=timedata('NoSample_100')
readlabdat('may16_1.csv',NoSample_100)

transducer_100=timedata('transducer_100')
readlabdat('apr27_21.csv',transducer_100)

Aluminium_100=timedata('Aluminium_100')
readlabdat('jun2_3.csv',Aluminium_100)

Sandstone_100=timedata('Sandstone_100')
readlabdat('jun2_8.csv',Sandstone_100)

Delrin_100=timedata('Delrin_100')
readlabdat('jun2_13.csv',Delrin_100)

Acrylic_100=timedata('Acrylic_100')
readlabdat('jun2_18.csv',Acrylic_100)

Bedding_100=timedata('Bedding_100')
readlabdat('jun2_23.csv', Bedding_100)

#plt.plot(NoSample_100.time*1e6,NoSample_100.data,label="No Sample - Gen to Osc")
#plt.plot(transducer_100.time*1e6,transducer_100.data,label="No Sample")
plt.plot(Aluminium_100.time*1e6,Aluminium_100.data,label="Aluminium")
plt.plot(Sandstone_100.time*1e6,Sandstone_100.data,label="Sandstone A")
plt.plot(Delrin_100.time*1e6,Delrin_100.data,label="Delrin")
plt.plot(Acrylic_100.time*1e6,Acrylic_100.data,label="Acrylic")
plt.plot(Bedding_100.time*1e6,Bedding_100.data,label="Sandstone B")

plt.ticklabel_format(axis='y', style='sci', scilimits=(-3,-3))
plt.legend()
plt.xlabel('Time ($\mu$s)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 100 kHz')
plt.savefig("compare_materials_100khz.jpeg",dpi=300)

# %% [markdown]
# # Comparing Materials - 300 kHz

# %%
transducer_300=timedata('transducer_300')
readlabdat('apr27_22.csv',transducer_300)

Aluminium_300=timedata('Aluminium_300')
readlabdat('jun2_4.csv',Aluminium_300)

Sandstone_300=timedata('Sandstone_300')
readlabdat('jun2_9.csv',Sandstone_300)

Delrin_300=timedata('Delrin_300')
readlabdat('jun2_14.csv',Delrin_300)

Acrylic_300=timedata('Acrylic_300')
readlabdat('jun2_19.csv',Acrylic_300)

Bedding_300=timedata('Bedding_300')
readlabdat('jun2_24.csv', Bedding_300)

#plt.plot(transducer_300.time*1e6,transducer_300.data,label="No Sample")
plt.plot(Aluminium_300.time*1e6,Aluminium_300.data,label="Aluminium")
plt.plot(Sandstone_300.time*1e6,Sandstone_300.data,label="Sandstone")
plt.plot(Delrin_300.time*1e6,Delrin_300.data,label="Delrin")
plt.plot(Acrylic_300.time*1e6,Acrylic_300.data,label="Acrylic")
plt.plot(Bedding_300.time*1e6,Bedding_300.data,label="Bedding")


plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 300 kHz')
plt.savefig("compare_materials_300khz.png",dpi=300)

# %% [markdown]
# # Comparing Materials - 500 kHz

# %%
transducer_500=timedata('transducer_500')
readlabdat('apr27_23.csv',transducer_500)

Aluminium_500=timedata('Aluminium_500')
readlabdat('jun2_5.csv',Aluminium_500)

Sandstone_500=timedata('Sandstone_500')
readlabdat('jun2_10.csv',Sandstone_500)

Delrin_500=timedata('Delrin_500')
readlabdat('jun2_15.csv',Delrin_500)

Acrylic_500=timedata('Acrylic_500')
readlabdat('jun2_20.csv',Acrylic_500)

Bedding_500=timedata('Bedding_500')
readlabdat('jun2_25.csv', Bedding_500)

#plt.plot(transducer_500.time*1e6,transducer_500.data,label="No Sample")
plt.plot(Aluminium_500.time*1e6,Aluminium_500.data,label="Aluminium")
plt.plot(Sandstone_500.time*1e6,Sandstone_500.data,label="Sandstone")
plt.plot(Delrin_500.time*1e6,Delrin_500.data,label="Delrin")
plt.plot(Acrylic_500.time*1e6,Acrylic_500.data,label="Acrylic")
plt.plot(Bedding_500.time*1e6,Bedding_500.data,label="Bedding")


plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 500 kHz')
plt.savefig("compare_materials_500khz.png",dpi=300)

# %% [markdown]
# # Comparing Materials - 800 kHz

# %%
transducer_800=timedata('transducer_800')
readlabdat('apr27_24.csv',transducer_800)

Aluminium_800=timedata('Aluminium_800')
readlabdat('jun2_6.csv',Aluminium_800)

Sandstone_800=timedata('Sandstone_800')
readlabdat('jun2_11.csv',Sandstone_800)

Delrin_800=timedata('Delrin_800')
readlabdat('jun2_16.csv',Delrin_800)

Acrylic_800=timedata('Acrylic_800')
readlabdat('jun2_21.csv',Acrylic_800)

Bedding_800=timedata('Bedding_800')
readlabdat('jun2_26.csv', Bedding_800)

#plt.plot(transducer_800.time*1e6,transducer_800.data,label="No Sample")
plt.plot(Aluminium_800.time*1e6,Aluminium_800.data,label="Aluminium")
plt.plot(Sandstone_800.time*1e6,Sandstone_800.data,label="Sandstone")
plt.plot(Delrin_800.time*1e6,Delrin_800.data,label="Delrin")
plt.plot(Acrylic_800.time*1e6,Acrylic_800.data,label="Acrylic")
plt.plot(Bedding_800.time*1e6,Bedding_800.data,label="Bedding")


plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 800 kHz')
plt.savefig("compare_materials_800khz.png",dpi=300)

# %% [markdown]
# # Comparing Materials - 1 MHz

# %%
transducer=timedata('transducer')
readlabdat('apr27_25.csv',transducer)

Aluminium=timedata('Aluminium')
readlabdat('jun2_7.csv',Aluminium)

Sandstone=timedata('Sandstone')
readlabdat('jun2_12.csv',Sandstone)

Delrin=timedata('Delrin')
readlabdat('jun2_17.csv',Delrin)

Acrylic=timedata('Acrylic_500')
readlabdat('jun2_22.csv',Acrylic)

Bedding=timedata('Bedding_500')
readlabdat('jun2_27.csv', Bedding)

#plt.plot(transducer.time*1e6,transducer.data,label="No Sample")
plt.plot(Aluminium.time*1e6,Aluminium.data,label="Aluminium")
plt.plot(Sandstone.time*1e6,Sandstone.data,label="Sandstone")
plt.plot(Delrin.time*1e6,Delrin.data,label="Delrin")
plt.plot(Acrylic.time*1e6,Acrylic.data,label="Acrylic")
plt.plot(Bedding.time*1e6,Bedding.data,label="Bedding")


plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 1 MHz')
plt.savefig("compare_materials_1Mhz.png",dpi=300)

# %% [markdown]
# # Normalized - comparing materials - 1 MHz

# %%
Aluminium_data = Aluminium.data - np.mean(Aluminium.data)
Sandstone_data = Sandstone.data - np.mean(Sandstone.data)
Delrin_data = Delrin.data - np.mean(Delrin.data)
Acrylic_data = Acrylic.data - np.mean(Acrylic.data)
Bedding_data = Bedding.data - np.mean(Bedding.data)

plt.plot(Aluminium.time*1e6,Aluminium_data/np.max(abs(Aluminium_data)),label="Aluminium")
plt.plot(Sandstone.time*1e6, Sandstone_data/np.max(abs(Sandstone_data)),label="Sandstone")
plt.plot(Delrin.time*1e6,Delrin_data/np.max(abs(Delrin_data)),label="Delrin")
plt.plot(Acrylic.time*1e6,Acrylic_data/np.max(abs(Acrylic_data)),label="Acrylic")
plt.plot(Bedding.time*1e6,Bedding_data/np.max(abs(Bedding_data)),label="Bedding")


plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Probe Amplitude (V)')
plt.title('Material Comparison - 1 MHz - Normalized')
plt.savefig("normalize_materials_1Mhz.png",dpi=300)

# %% [markdown]
# # FFT - Aluminium

# %%
# 100 kHz
n_Aluminium_100=np.size(Aluminium_100.time)
dt_Aluminium_100=(Aluminium_100.time[2]-Aluminium_100.time[1])*1e6
f_Aluminium_100=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_100,d=dt_Aluminium_100))*1000
FT_Aluminium_100=np.fft.fftshift(np.fft.fft(Aluminium_100.data))

# 300 kHz
n_Aluminium_300=np.size(Aluminium_300.time)
dt_Aluminium_300=(Aluminium_300.time[2]-Aluminium_300.time[1])*1e6
f_Aluminium_300=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_300,d=dt_Aluminium_300))*1000
FT_Aluminium_300=np.fft.fftshift(np.fft.fft(Aluminium_300.data))

# 500 kHz
n_Aluminium_500=np.size(Aluminium_500.time)
dt_Aluminium_500=(Aluminium_500.time[2]-Aluminium_500.time[1])*1e6
f_Aluminium_500=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_500,d=dt_Aluminium_500))*1000
FT_Aluminium_500=np.fft.fftshift(np.fft.fft(Aluminium_500.data))

# 800 kHz
n_Aluminium_800=np.size(Aluminium_800.time)
dt_Aluminium_800=(Aluminium_800.time[2]-Aluminium_800.time[1])*1e6
f_Aluminium_800=np.fft.fftshift(np.fft.fftfreq(n_Aluminium_800,d=dt_Aluminium_800))*1000
FT_Aluminium_800=np.fft.fftshift(np.fft.fft(Aluminium_800.data))

# 1 MHz
n_Aluminium=np.size(Aluminium.time)
dt_Aluminium=(Aluminium.time[2]-Aluminium.time[1])*1e6
f_Aluminium=np.fft.fftshift(np.fft.fftfreq(n_Aluminium,d=dt_Aluminium))*1000
FT_Aluminium=np.fft.fftshift(np.fft.fft(Aluminium.data))

# %%
plt.plot(f_Aluminium,np.abs(FT_Aluminium), label="1 MHz")
plt.plot(f_Aluminium_800,np.abs(FT_Aluminium_800), label="800 kHz")
plt.plot(f_Aluminium_500,np.abs(FT_Aluminium_500), label="500 kHz")
plt.plot(f_Aluminium_300,np.abs(FT_Aluminium_300), label="300 kHz")
plt.plot(f_Aluminium_100,np.abs(FT_Aluminium_100), label="100 kHz")
plt.xlim([-100,1500])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('FFT - Aluminium')
# Out:
# Text(0.5, 1.0, 'FFT - Aluminium')

# %%
plt.plot(f_Aluminium_100,np.abs(FT_Aluminium_100), label="100 kHz")
plt.xlim([0,500])
# Out:
# (0.0, 500.0)

# %% [markdown]
# # FFT from no sample

# %%
# transducers 1 and 2, no sample with honey

n_p12_100_h=np.size(p12_100_h.time)
dt_p12_100_h=(p12_100_h.time[2]-p12_100_h.time[1])*1e6
f_p12_100_h=np.fft.fftshift(np.fft.fftfreq(n_p12_100_h,d=dt_p12_100_h))*1000
FT_p12_100_h=np.fft.fftshift(np.fft.fft(p12_100_h.data - np.mean(p12_100_h.data)))

n_p12_300_h=np.size(p12_300_h.time)
dt_p12_300_h=(p12_300_h.time[2]-p12_300_h.time[1])*1e6
f_p12_300_h=np.fft.fftshift(np.fft.fftfreq(n_p12_300_h,d=dt_p12_300_h))*1000
FT_p12_300_h=np.fft.fftshift(np.fft.fft(p12_300_h.data - np.mean(p12_300_h.data)))

n_p12_500_h=np.size(p12_500_h.time)
dt_p12_500_h=(p12_500_h.time[2]-p12_500_h.time[1])*1e6
f_p12_500_h=np.fft.fftshift(np.fft.fftfreq(n_p12_500_h,d=dt_p12_500_h))*1000
FT_p12_500_h=np.fft.fftshift(np.fft.fft(p12_500_h.data - np.mean(p12_500_h.data)))

n_p12_800_h=np.size(p12_800_h.time)
dt_p12_800_h=(p12_800_h.time[2]-p12_800_h.time[1])*1e6
f_p12_800_h=np.fft.fftshift(np.fft.fftfreq(n_p12_800_h,d=dt_p12_800_h))*1000
FT_p12_800_h=np.fft.fftshift(np.fft.fft(p12_800_h.data - np.mean(p12_800_h.data)))

n_p12_1000_h=np.size(p12_1000_h.time)
dt_p12_1000_h=(p12_1000_h.time[2]-p12_1000_h.time[1])*1e6
f_p12_1000_h=np.fft.fftshift(np.fft.fftfreq(n_p12_1000_h,d=dt_p12_1000_h))*1000
FT_p12_1000_h=np.fft.fftshift(np.fft.fft(p12_1000_h.data - np.mean(p12_1000_h.data)))

# %%
plt.plot(f_p12_100_h,np.abs(FT_p12_100_h), label="100 kHz")
plt.plot(f_p12_300_h,np.abs(FT_p12_300_h), label="300 kHz")
plt.plot(f_p12_500_h,np.abs(FT_p12_500_h), label="500 kHz")
plt.plot(f_p12_800_h,np.abs(FT_p12_800_h), label="800 kHz")
plt.plot(f_p12_1000_h,np.abs(FT_p12_1000_h), label="1 MHz")

plt.xlim([0,1500])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('FFT of P-wave Transducer and Honey - No Sample')
plt.savefig("NoSampleFFTp12_h.png",dpi=300)

# %% [markdown]
# # Gen to Scope FFT - 1,4,cont.

# %%
GS_1=timedata('GS_1')
readlabdat('jun27_1.csv',GS_1)

GS_4=timedata('GS_4')
readlabdat('jun27_2.csv',GS_4)

GS_C=timedata('GS_C')
readlabdat('jun27_3.csv',GS_C)

# FFT

n_GS_1=np.size(GS_1.time)
dt_GS_1=(GS_1.time[2]-GS_1.time[1])*1e6
f_GS_1=np.fft.fftshift(np.fft.fftfreq(n_GS_1,d=dt_GS_1))*1000
FT_GS_1=np.fft.fftshift(np.fft.fft(GS_1.data - np.mean(GS_1.data)))

n_GS_4=np.size(GS_4.time)
dt_GS_4=(GS_4.time[2]-GS_4.time[1])*1e6
f_GS_4=np.fft.fftshift(np.fft.fftfreq(n_GS_4,d=dt_GS_4))*1000
FT_GS_4=np.fft.fftshift(np.fft.fft(GS_4.data - np.mean(GS_4.data)))

n_GS_C=np.size(GS_C.time)
dt_GS_C=(GS_C.time[2]-GS_C.time[1])*1e6
f_GS_C=np.fft.fftshift(np.fft.fftfreq(n_GS_C,d=dt_GS_C))*1000
FT_GS_C=np.fft.fftshift(np.fft.fft(GS_C.data - np.mean(GS_C.data)))

# %%
f_GS_4[2]-f_GS_4[1]
# Out:
# 50.0

# %%
plt.plot(f_GS_1,np.abs(FT_GS_1), '-o', label="1 Cycle")
plt.plot(f_GS_4,np.abs(FT_GS_4),'-o', label="4 Cycles")
plt.plot(f_GS_C,np.abs(FT_GS_C),'-o', label="Continuous")


plt.xlim([0,1000])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Cycle # FFT Comparison: Generator to Scope - 2 us')
#plt.savefig("NoSampleFFTp12_h.png",dpi=300)
# short time, 2us
# Out:
# Text(0.5, 1.0, 'Cycle # FFT Comparison: Generator to Scope - 2 us')

# %%
# Redo above code but with longer time - 10 us

GS_1=timedata('GS_1')
readlabdat('jun27_4.csv',GS_1)

GS_4=timedata('GS_4')
readlabdat('jun27_5.csv',GS_4)

GS_C=timedata('GS_C')
readlabdat('jun27_6.csv',GS_C)

# FFT

n_GS_1=np.size(GS_1.time)
dt_GS_1=(GS_1.time[2]-GS_1.time[1])*1e6
f_GS_1=np.fft.fftshift(np.fft.fftfreq(n_GS_1,d=dt_GS_1))*1000
FT_GS_1=np.fft.fftshift(np.fft.fft(GS_1.data - np.mean(GS_1.data)))

n_GS_4=np.size(GS_4.time)
dt_GS_4=(GS_4.time[2]-GS_4.time[1])*1e6
f_GS_4=np.fft.fftshift(np.fft.fftfreq(n_GS_4,d=dt_GS_4))*1000
FT_GS_4=np.fft.fftshift(np.fft.fft(GS_4.data - np.mean(GS_4.data)))

n_GS_C=np.size(GS_C.time)
dt_GS_C=(GS_C.time[2]-GS_C.time[1])*1e6
f_GS_C=np.fft.fftshift(np.fft.fftfreq(n_GS_C,d=dt_GS_C))*1000
FT_GS_C=np.fft.fftshift(np.fft.fft(GS_C.data - np.mean(GS_C.data)))

plt.plot(f_GS_1,np.abs(FT_GS_1), label="1 Cycle")
plt.plot(f_GS_4,np.abs(FT_GS_4), label="4 Cycles")
plt.plot(f_GS_C,np.abs(FT_GS_C), label="Continuous")


plt.xlim([0,1000])
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Intensity')
plt.title('Cycle # FFT Comparison: Generator to Scope - 10 us')
#plt.savefig("NoSampleFFTp12_h.png",dpi=300)
# Out:
# Text(0.5, 1.0, 'Cycle # FFT Comparison: Generator to Scope - 10 us')
